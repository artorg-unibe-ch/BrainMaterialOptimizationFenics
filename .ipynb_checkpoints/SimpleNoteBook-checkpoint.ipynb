# %%
# import sys
# sys.path.insert(0, "/home/msimon/Desktop/FEniCS/Tests")
import IdealSimpleFunctions as ISF

# %%
ConstitutiveModels = ['Ogden', 'Neo-Hookean']
ConstitutiveModel = ConstitutiveModels[0]

NumberElementsTested = [1, 2, 3, 5, 10, 20]
NumberElements = NumberElementsTested[1]

LoadCases = ['Compression', 'Tension']
RelativeWeights = [1,1]


FinalRelativeStretch = 0.1
RelativeStepSize     = 0.02


#for NumberElements in NumberElementsTested:
ResultsOptimization = ISF.ParametersOptimization(ConstitutiveModel, NumberElements, LoadCases, RelativeWeights, FinalRelativeStretch, RelativeStepSize)
# Out:
# Cost: 0.007858368345921001
# Cost: 0.007858364205881957
# Cost: 0.007858367170295776
# Cost: 0.007858368342100757
# Cost: 0.0569976055339774
# Cost: 0.056997627072721255
# Cost: 0.05699761504219024
# Cost: 0.05699760532546679
# Cost: 0.006884682740641044
# Cost: 0.006884681198757673
# Cost: 0.006884682839711496
# Cost: 0.006884682685290697
# Cost: 0.0064089103802420725
# Cost: 0.006408909731808587
# Cost: 0.006408910533293177
# Cost: 0.00640891029217152
# Cost: 0.0063617032773389155
# Cost: 0.00636170254851114
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703344424197
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617034722557525
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006397675455122069
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006397674212192823
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006397675203133559
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006397675471569499
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006364362042328105
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006364361176120208
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.00636436191925718
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006364362028625631
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006362120376411967
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006362119717746722
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.00636212044396645
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063621204202123785
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361752119013606
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361751369797631
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361751878111301
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361752150506727
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361716006982356
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361715113654926
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361715860413749
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361715875895818
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617061683016824
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361705405494603
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361706140452565
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361706155642648
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703782708188
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703044520238
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703778914636
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703878423556
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617034383684065
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361702707498279
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703311064309
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.00636170330256886
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703354530053
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361702524393775
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703358090399
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703351668404
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617033990023
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361702721057157
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617032823796976
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703370565967
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.0063617032334921195
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361702573312279
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703235161791
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.006361703318354021
# Final Nu = 0.495
# Final Mu = 0.664
# Final Alpha = -24.300

# %%
LoadCases = ['Compression', 'Tension']
RelativeWeights = [1,1,1]
FinalRelativeStretch = 0.1
RelativeStepSize     = 0.01
Dimensions = [5,5,5]
NumberElements = 5
# Mu, Alpha = ResOpt.x
Mu, Alpha = [0.274, -31.279]
Nu = 0.454
D  = 3*(1-2*Nu)/(Mu*(1+Nu))     # (1/kPa)
print(D)

SF.CostFunction([Nu, Mu, Alpha], Dimensions, NumberElements, LoadCases, RelativeWeights, FinalRelativeStretch, RelativeStepSize, Plot = True)

# %%
LoadCases = ['Compression', 'Tension', 'SimpleShear']
RelativeWeights = [1,1,1]
FinalRelativeStretch = 0.1
RelativeStepSize     = 0.01
Dimensions = [5,5,5]
NumberElements = 5
# Mu, Alpha = ResOpt.x
Mu, Alpha = [0.458, -59.367]
D = 1.026
K = 2/D
Nu = (3*(K/Mu)-2)/(6*(K/Mu)+2)
print(Nu)

SF.CostFunction([Nu, Mu, Alpha], Dimensions, NumberElements, LoadCases, RelativeWeights, FinalRelativeStretch, RelativeStepSize, Plot = True)

# %%
import pandas as pd                       # Allows to use data in tables
import matplotlib.pyplot as plt           # Allows to do plots

dt = pd.read_csv('OptimizationTime.txt', header=None)

plt.rc('figure', figsize=[12,7])
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.cla()
ax.plot([1,2,3,4,5,6,7,8],dt,  color = 'r', linestyle = '--', marker = 'o', markersize = 8, fillstyle='none')
ax.set_xlabel('Number of elements by edge (-)')
ax.set_ylabel('Optimization time (s)')
ax.xaxis.set_major_locator(plt.MultipleLocator(1))
