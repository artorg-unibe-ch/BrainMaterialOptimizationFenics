# %%
# import sys
# sys.path.insert(0, "/home/msimon/Desktop/FEniCS/Tests")
import Optimization_FunctionUsed as OF

# %%
# Parameters
Tissues = ['Cortex', 'Basal Ganglia', 'Corona Radiata', 'Corpus Callosum']
ConstitutiveModels = ['Ogden', 'Neo-Hookean']
NumberElementsTested = [1, 2, 3, 5, 10, 20]
BCsTypes = ['Ideal','Real']

# Settings
Tissue  = Tissues[3]
ConstitutiveModel  = ConstitutiveModels[0]
NumberElements = NumberElementsTested[5]
BCsType  = BCsTypes[1] + ' Boundary Conditions'
LoadCases = ['Compression', 'Tension', 'SimpleShear']
RelativeWeights = [1,1,1]
FinalRelativeStretch = 0.1
RelativeStepSize     = 0.01

#for NumberElements in NumberElementsTested:
ResultsOptimization = OF.ParametersOptimization(Tissue, ConstitutiveModel, NumberElements, BCsType, LoadCases, RelativeWeights, FinalRelativeStretch, RelativeStepSize)
# Out:
# Cost: 12.561830362768033
# Cost: 12.561830381189901
# Cost: 12.561830619918183
# Cost: 12.561830359472703
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.2690071029570977
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.2690071058496166
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.2690071656424522
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.2690071030361618
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.2363548447115817
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.236354847536466
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.236354904013218
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.236354844796858
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.113714778804267
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.1137147813526707
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.1137148249127204
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 1.1137147789120194
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.673291081092002
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.673291080469553
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.6732910328437146
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.6732910813318201
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.47308800315453386
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.4730880022031922
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.473087964473024
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.47308800344148283
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.2044890894079039
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.2044890911819055
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.20448909046264044
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.20448908958302536
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05067543447068982
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05067543555681383
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05067543957595224
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.050675434481091096
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05227771858457092
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05227771777499535
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05227771256192599
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.05227771872827874
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03828047827480822
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03828047840309804
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.038280478157573995
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03828047835435202
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.038262303653480635
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03826230377470576
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03826230349604604
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03826230373351153
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03820355847510494
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03820355856805189
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.038203558156660135
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03820355855697941
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03790857427553846
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03790857430576034
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.037908573613373416
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.037908574360826
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.036837539127811625
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.036837539008834776
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.036837537681851766
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03683753921964156
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03280611804495108
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.032806118187407675
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03280611841698616
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.03280611810846038
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.02140708162481933
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.02140708172511376
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.021407083242995607
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.02140708163985407
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.015161904710609278
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.015161904363983401
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.015161905413188041
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.015161904704272013
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.09624123148548584
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.09624123059577265
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.09624120497756777
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.09624123168505633
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010430727766021636
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010430727825865614
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010430727745233953
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010430727767206563
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010331288755002228
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010331288782738361
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010331288847951156
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010331288753754164
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010320632379843363
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010320632368379346
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010320632313974317
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010320632380634591
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319310568986141
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319310569794977
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319310576978553
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319310568945741
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319338985165268
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.01031933898544647
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319338985135878
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319338985107866
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319307321488844
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319307322091806
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.01031930732718322
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319307321440858
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319306764573174
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.01031930676450228
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319306763985838
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Cost: 0.010319306764489887
# Final Lambda = 1.219
# Final Mu = 0.352
# Final Alpha = -30.579
